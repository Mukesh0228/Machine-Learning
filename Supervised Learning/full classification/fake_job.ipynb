# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
df = pd.read_csv("fake_job_postings.csv")
df.dropna(axis = 0, inplace = True)
df
# Out:
#        job_id                                              title  \
# 6           7                              Head of Content (m/f)
# 15         16                         VP of Sales - Vault Dragon
# 23         24  Vice President, Sales and Sponsorship (Busines...
# 98         99                                    IC&E Technician
# 102       103                            Marketing Administrator
# ...       ...                                                ...
# 17734   17735                    Customer Service Representative
# 17759   17760                    Customer Service Representative
# 17813   17814                    Customer Service Representative
# 17849   17850                             Communication Designer
# 17865   17866  Portfolio Development Associate - Paris & rest...
#
#                     location          department   salary_range  \
# 6             DE, BE, Berlin          ANDROIDPIT    20000-28000
# ...

# %%
df["Sentance"] = df["title"] + df["company_profile"] + df["description"] + df["requirements"] + df["benefits"]

# %%
x = df.Sentance
y = df.fraudulent

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, random_state = 42, train_size = 0.8)

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized", TfidfVectorizer()),
        ("model",LogisticRegression())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', TfidfVectorizer()),
#                 ('model', LogisticRegression())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       560
#            1       1.00      0.27      0.43        59
#
#     accuracy                           0.93       619
#    macro avg       0.96      0.64      0.69       619
# weighted avg       0.94      0.93      0.91       619

# %% [markdown]
# *OBSERVATION*
#
# 1). LogisticRegression train predict --> 69% and test Predict --> 72%
#
# 2). it's preform underfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97       142
#            1       1.00      0.31      0.47        13
#
#     accuracy                           0.94       155
#    macro avg       0.97      0.65      0.72       155
# weighted avg       0.95      0.94      0.93       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized",TfidfVectorizer()),
        ("model",DecisionTreeClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', TfidfVectorizer()),
#                 ('model', DecisionTreeClassifier())])

# %%
ytrain = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       560
#            1       1.00      0.27      0.43        59
#
#     accuracy                           0.93       619
#    macro avg       0.96      0.64      0.69       619
# weighted avg       0.94      0.93      0.91       619

# %% [markdown]
# *OBSERVATION*
#
# 1). DecisionTreeClass train predict --> 69% and test Predict --> 94%
#
# 2). it's preform underfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       142
#            1       0.86      0.92      0.89        13
#
#     accuracy                           0.98       155
#    macro avg       0.93      0.95      0.94       155
# weighted avg       0.98      0.98      0.98       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized",TfidfVectorizer()),
        ("model",RandomForestClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', TfidfVectorizer()),
#                 ('model', RandomForestClassifier())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). RandomForestClassifier train predict --> 100% and test Predict --> 98%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       142
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99       155
#    macro avg       1.00      0.96      0.98       155
# weighted avg       0.99      0.99      0.99       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized",TfidfVectorizer()),
        ("model",XGBClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', TfidfVectorizer()),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
# ...

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). XGBClassifier train predict --> 100% and test Predict --> 92%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       142
#            1       0.85      0.85      0.85        13
#
#     accuracy                           0.97       155
#    macro avg       0.92      0.92      0.92       155
# weighted avg       0.97      0.97      0.97       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorizer",TfidfVectorizer()),
        ("model",KNeighborsClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()),
#                 ('model', KNeighborsClassifier())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       0.97      0.97      0.97        59
#
#     accuracy                           0.99       619
#    macro avg       0.98      0.98      0.98       619
# weighted avg       0.99      0.99      0.99       619

# %% [markdown]
# *OBSERVATION*
#
# 1). KNeighboresClassifier train predict --> 98% and test Predict --> 94%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       142
#            1       0.86      0.92      0.89        13
#
#     accuracy                           0.98       155
#    macro avg       0.93      0.95      0.94       155
# weighted avg       0.98      0.98      0.98       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized",TfidfVectorizer()),
        ("model",SVC())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', TfidfVectorizer()), ('model', SVC())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). SVC train predict --> 100% and test Predict --> 98%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       142
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99       155
#    macro avg       1.00      0.96      0.98       155
# weighted avg       0.99      0.99      0.99       155

# %%
main_pipe = Pipeline(
    steps=[
    ("vectorized", CountVectorizer()),
    ("model", LogisticRegression())
])

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', CountVectorizer()),
#                 ('model', LogisticRegression())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). LogisticRegression train predict --> 100% and test Predict --> 98%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       142
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99       155
#    macro avg       1.00      0.96      0.98       155
# weighted avg       0.99      0.99      0.99       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized", CountVectorizer()),
        ("model",DecisionTreeClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', CountVectorizer()),
#                 ('model', DecisionTreeClassifier())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). DecisionTreeClassifier train predict --> 100% and test Predict --> 98%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       142
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99       155
#    macro avg       1.00      0.96      0.98       155
# weighted avg       0.99      0.99      0.99       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized", CountVectorizer()),
        ("model",RandomForestClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', CountVectorizer()),
#                 ('model', RandomForestClassifier())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). RandomForestClassifier train predict --> 100% and test Predict --> 98%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       142
#            1       1.00      0.92      0.96        13
#
#     accuracy                           0.99       155
#    macro avg       1.00      0.96      0.98       155
# weighted avg       0.99      0.99      0.99       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized", CountVectorizer()),
        ("model",XGBClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', CountVectorizer()),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=None, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric=None,
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
# ...

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       560
#            1       1.00      1.00      1.00        59
#
#     accuracy                           1.00       619
#    macro avg       1.00      1.00      1.00       619
# weighted avg       1.00      1.00      1.00       619

# %% [markdown]
# *OBSERVATION*
#
# 1). XGBClassifier train predict --> 100% and test Predict --> 92%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       142
#            1       0.85      0.85      0.85        13
#
#     accuracy                           0.97       155
#    macro avg       0.92      0.92      0.92       155
# weighted avg       0.97      0.97      0.97       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized",CountVectorizer()),
        ("model",KNeighborsClassifier())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', CountVectorizer()),
#                 ('model', KNeighborsClassifier())])

# %%
ytrain_pred = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       560
#            1       0.88      0.90      0.89        59
#
#     accuracy                           0.98       619
#    macro avg       0.94      0.94      0.94       619
# weighted avg       0.98      0.98      0.98       619

# %% [markdown]
# *OBSERVATION*
#
# 1). KNeighborsClassifier train predict --> 94% and test Predict --> 88%
#
# 2). it's preform goodfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98       142
#            1       0.73      0.85      0.79        13
#
#     accuracy                           0.96       155
#    macro avg       0.86      0.91      0.88       155
# weighted avg       0.96      0.96      0.96       155

# %%
main_pipe = Pipeline(
    steps = [
        ("vectorized",CountVectorizer()),
        ("model",SVC())
    ]
)

# %%
main_pipe.fit(xtrain,ytrain)
# Out:
# Pipeline(steps=[('vectorized', CountVectorizer()), ('model', SVC())])

# %%
ytrain_pred  = main_pipe.predict(xtrain)
print(classification_report(ytrain,ytrain_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98       560
#            1       1.00      0.54      0.70        59
#
#     accuracy                           0.96       619
#    macro avg       0.98      0.77      0.84       619
# weighted avg       0.96      0.96      0.95       619

# %% [markdown]
# *OBSERVATION*
#
# 1). SVC train predict --> 84% and test Predict --> 61%
#
# 2). it's preform Overfit

# %%
ytest_pred = main_pipe.predict(xtest)
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       142
#            1       1.00      0.15      0.27        13
#
#     accuracy                           0.93       155
#    macro avg       0.96      0.58      0.61       155
# weighted avg       0.93      0.93      0.90       155
